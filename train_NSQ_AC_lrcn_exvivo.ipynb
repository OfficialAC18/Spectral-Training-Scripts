# %%
#Call Main and let it run
from training_two_class_exvivo_lrcn import main

# %%
DATASET_DIR = "/scratch/users/k23058970/Spectral Dataset/NSQ vs AC (Revised)"
main(dataset_dir=DATASET_DIR,dset_name = "NSQ vs AC LRCN")
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-07-30 13:31:53</td></tr>
# <tr><td>Running for: </td><td>18:51:26.27        </td></tr>
# <tr><td>Memory:      </td><td>38.3/1007.5 GiB    </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=16<br>Bracket: Iter 960.000: -1.7880873489379883 | Iter 480.000: -1.0714394783973693 | Iter 240.000: -1.5963009077310564 | Iter 120.000: -1.881993134021759 | Iter 60.000: -1.7063459849357605 | Iter 30.000: -1.5881007850170135 | Iter 15.000: -1.6278248929977417<br>Logical resource usage: 48.0/96 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A30)
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
# ...
