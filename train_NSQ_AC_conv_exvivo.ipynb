# %%
#Call Main and let it run
from training_two_class_exvivo_conv import main

# %%
DATASET_DIR = "/scratch/users/k23058970/Spectral Dataset/NSQ vs AC (Revised)"
main(dataset_dir=DATASET_DIR,dset_name = "NSQ vs AC Conv")
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-07-30 13:25:07</td></tr>
# <tr><td>Running for: </td><td>20:20:20.45        </td></tr>
# <tr><td>Memory:      </td><td>40.2/1007.5 GiB    </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=22<br>Bracket: Iter 960.000: None | Iter 480.000: -1.6386909246444703 | Iter 240.000: -0.6006952719390393 | Iter 120.000: -0.5063382630050183 | Iter 60.000: -0.41805569551885124 | Iter 30.000: -0.5036212901771069 | Iter 15.000: -0.9444940823316574<br>Logical resource usage: 96.0/96 CPUs, 0.8/1 GPUs (0.0/1.0 accelerator_type:A30)
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#
# ...
