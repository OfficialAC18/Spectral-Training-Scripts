# %%
#Call Main and let it run
from training_two_class_exvivo_conv import main

# %%
DATASET_DIR =DATASET_DIR = "/scratch/users/k23058970/Spectral Dataset/NSQ vs All (Revised)"
main(dataset_dir=DATASET_DIR,dset_name = "NSQ vs All Conv")
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-07-30 22:43:21</td></tr>
# <tr><td>Running for: </td><td>09:10:53.95        </td></tr>
# <tr><td>Memory:      </td><td>119.2/1007.5 GiB   </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=4<br>Bracket: Iter 960.000: None | Iter 480.000: None | Iter 240.000: None | Iter 120.000: None | Iter 60.000: -0.41656982668421483 | Iter 30.000: -0.37340262227437715 | Iter 15.000: -0.38996801484714855<br>Logical resource usage: 96.0/96 CPUs, 0.8/1 GPUs (0.0/1.0 accelerator_type:A30)
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#   ... 30 more trials not shown (30 PENDING)
# ...
