# %%
#Call Main and let it run
from training import main

# %%
DATASET_DIR = "/home/akchunya/Akchunya/MSc Thesis/Simulated Spectra Dataset/Single"
main(dataset_dir=DATASET_DIR)

# %%
DATASET_DIR = "/scratch/users/k23058970/Spectral Dataset/All Class"
main(dataset_dir=DATASET_DIR)
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-06-24 14:35:34</td></tr>
# <tr><td>Running for: </td><td>12:56:48.47        </td></tr>
# <tr><td>Memory:      </td><td>16.0/503.5 GiB     </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=2<br>Bracket: Iter 960.000: None | Iter 480.000: None | Iter 240.000: -0.37165839055722416 | Iter 120.000: -0.40256242643703116 | Iter 60.000: -0.5447072617032311 | Iter 30.000: -0.6563559022816745 | Iter 15.000: -0.930038965290243<br>Logical resource usage: 72.0/72 CPUs, 0.6000000000000001/1 GPUs (0.0/1.0 accelerator_type:A100)
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
# ...
