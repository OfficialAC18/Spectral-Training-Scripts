# %%
#Call Main and let it run
from training_exvivo_lrcn import main

# %%
DATASET_DIR = "/scratch/users/k23058970/Spectral Dataset/All Class (Revised)"
main(dataset_dir=DATASET_DIR,dset_name = "SMART All Class LRCN")
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-07-29 03:52:34</td></tr>
# <tr><td>Running for: </td><td>11:29:28.13        </td></tr>
# <tr><td>Memory:      </td><td>109.8/1007.5 GiB   </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=15<br>Bracket: Iter 960.000: None | Iter 480.000: None | Iter 240.000: None | Iter 120.000: -1.8648621765050022 | Iter 60.000: -1.406956212087111 | Iter 30.000: -1.6478947856209494 | Iter 15.000: -1.607804772528735<br>Logical resource usage: 48.0/96 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:A30)
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
# ...
